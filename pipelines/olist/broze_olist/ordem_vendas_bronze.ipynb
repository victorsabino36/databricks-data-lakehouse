# %%
from pyspark.sql.functions import current_timestamp

# %%
df = spark.read.csv("/Volumes/data/lainding/lainding/dataset-olist/olist_orders_dataset.csv", header=True)

# %%
df.display()

# %%
# %sql
use catalog `workspace`; select * from `olist_bronze`.`view_pedidos` limit 100;

# %%
# %sql
use catalog `workspace`; select * from `olist_bronze`.`view_pedidos` limit 100;

# %%
df_date_ingestao = df.withColumn("data_ingestao", current_timestamp())

df_date_ingestao.printSchema()

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.olist_bronze.pedidos_bronze (
 order_id string,
 customer_id string,
 order_status string,
 order_purchase_timestamp string,
 order_approved_at string,
 order_delivered_carrier_date string,
 order_delivered_customer_date string,
 order_estimated_delivery_date string,
 data_ingestao timestamp 
)

# %%
df_date_ingestao.write.mode("overwrite").saveAsTable("workspace.olist_bronze.pedidos_bronze")

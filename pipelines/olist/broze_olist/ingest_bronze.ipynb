# %%
from pyspark.sql.functions import current_timestamp

# %%
caminho_file = "/Volumes/data/lainding/lainding/dataset-olist/"

# %%
table_name = []
for i in dbutils.fs.ls(caminho_file):
      print(i.name.split('/')[0])
      table_name.append(i.name.split(".")[0])

# %%
table_name

# %%
from pyspark.sql.functions import from_utc_timestamp, date_format
from pyspark.sql.types import TimestampType

for i in table_name: 
    path = "/Volumes/data/lainding/lainding/dataset-olist/" + i + ".csv"
    df = spark.read.csv(path, header=True)
    df_date_ingestao = df.withColumn("data_ingestao", current_timestamp())
    df_date_ingestao.write.mode("overwrite").format("delta").saveAsTable("workspace.olist_bronze." + i + "_bronze")

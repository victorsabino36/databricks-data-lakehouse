# %%
# %sql
-- 1. Registrar a localização física da Gold (Isso resolve o erro)
CREATE EXTERNAL LOCATION IF NOT EXISTS loc_bronze
URL 'abfss://bronze@sabinoanalyticsdatalake.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred_sabino_datalake`);

-- 2. Agora sim, criar o Schema lógico vinculado a essa localização
CREATE SCHEMA IF NOT EXISTS sabino_analytics.bronze
MANAGED LOCATION 'abfss://bronze@sabinoanalyticsdatalake.dfs.core.windows.net/';

# %%
# %sql
-- 1. Registrar a localização física da Gold (Isso resolve o erro)
CREATE EXTERNAL LOCATION IF NOT EXISTS loc_silver
URL 'abfss://silver@sabinoanalyticsdatalake.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred_sabino_datalake`);

-- 2. Agora sim, criar o Schema lógico vinculado a essa localização
CREATE SCHEMA IF NOT EXISTS sabino_analytics.silver
MANAGED LOCATION 'abfss://silver@sabinoanalyticsdatalake.dfs.core.windows.net/';

# %%
# %sql
-- 1. Registrar a localização física da Gold (Isso resolve o erro)
CREATE EXTERNAL LOCATION IF NOT EXISTS loc_gold
URL 'abfss://gold@sabinoanalyticsdatalake.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred_sabino_datalake`);

-- 2. Agora sim, criar o Schema lógico vinculado a essa localização
CREATE SCHEMA IF NOT EXISTS sabino_analytics.gold
MANAGED LOCATION 'abfss://gold@sabinoanalyticsdatalake.dfs.core.windows.net/';
